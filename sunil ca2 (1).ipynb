# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("file:///C:/Users/hgjygj/Downloads/chocolate.csv")
data.head()
# Out:
#    Unnamed: 0   ref   company company_location  review_date  \
# 0           0  2454      5150            U.S.A         2019
# 1           1  2458      5150            U.S.A         2019
# 2           2  2454      5150            U.S.A         2019
# 3           3   797  A. Morin           France         2012
# 4           4   797  A. Morin           France         2012
#
#   country_of_bean_origin specific_bean_origin_or_bar_name  cocoa_percent  \
# 0             Madagascar           Bejofo Estate, batch 1           76.0
# 1     Dominican republic                  Zorzal, batch 1           76.0
# 2               Tanzania            Kokoa Kamili, batch 1           76.0
# 3                   Peru                             Peru           63.0
# 4                Bolivia                          Bolivia           70.0
#
#    rating  counts_of_ingredients  ...       cocoa_butter          vanilla  \
# 0     NaN                      3  ...  have_cocoa_butter  have_not_vanila
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                             0
# ref                                    0
# company                                0
# company_location                       0
# review_date                            0
# country_of_bean_origin                 0
# specific_bean_origin_or_bar_name       0
# cocoa_percent                          0
# rating                                28
# counts_of_ingredients                  0
# beans                                  0
# cocoa_butter                           0
# vanilla                                0
# lecithin                               0
# salt                                   0
# sugar                                  0
# sweetener_without_sugar                0
# first_taste                            0
# second_taste                          77
# third_taste                          620
# fourth_taste                        1982
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        2224 non-null   int64
#  1   ref                               2224 non-null   int64
#  2   company                           2224 non-null   object
#  3   company_location                  2224 non-null   object
#  4   review_date                       2224 non-null   int64
#  5   country_of_bean_origin            2224 non-null   object
#  6   specific_bean_origin_or_bar_name  2224 non-null   object
#  7   cocoa_percent                     2224 non-null   float64
#  8   rating                            2224 non-null   float64
#  9   counts_of_ingredients             2224 non-null   int64
#  10  beans                             2224 non-null   object
# ...

# %%
#dataclening
Rating_Mean=data.rating.mean()
Rating_Mean
# Out:
# 3.1958561020036433

# %%
data.rating.fillna(Rating_Mean,inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                             0
# ref                                    0
# company                                0
# company_location                       0
# review_date                            0
# country_of_bean_origin                 0
# specific_bean_origin_or_bar_name       0
# cocoa_percent                          0
# rating                                 0
# counts_of_ingredients                  0
# beans                                  0
# cocoa_butter                           0
# vanilla                                0
# lecithin                               0
# salt                                   0
# sugar                                  0
# sweetener_without_sugar                0
# first_taste                            0
# second_taste                          77
# third_taste                          620
# fourth_taste                        1982
# dtype: int64

# %%
#boxplot
sns.boxplot(data.rating)
plt.show()
# Out:
# C:\Users\hgjygj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Histoplot
sns.histplot(data.counts_of_ingredients)
plt.show()

# %%
#rugplot
sns.rugplot(data.fourth_taste)
plt.show()

# %%
#vilionplot
sns.violinplot(data.counts_of_ingredients)
plt.show()
# Out:
# C:\Users\hgjygj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#stripplot
sns.stripplot(data.rating)
plt.show()
# Out:
# C:\Users\hgjygj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#  PIE CHART
df = data['rating'].value_counts()
plt.pie(df, labels=df.index, autopct="%.0f%%");

# %%
# NUMERICAL - NUMERICAL ASSOCIATIONS
plt.scatter(data.company_location,data.rating)
plt.show()

# %%
# Correlation Matrix
sns.heatmap(data[["counts_of_ingredients","rating"]].corr(), annot=True, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
# Violin Plot
sns.violinplot(x=data["cocoa_percent"], y=data["counts_of_ingredients"])
# Out:
# <AxesSubplot:xlabel='cocoa_percent', ylabel='counts_of_ingredients'>

# %%
#heatmap
plt.subplots(figsize=(29,8))
corr = data.corr()
sns.heatmap(corr,annot=True,
           xticklabels = corr.columns.values,
           yticklabels = corr.columns.values);
plt.show()

# %%
#pairplot
sns.pairplot(data,hue="company_location",size=3)
# Out:
# C:\Users\hgjygj\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
data.mean()
# Out:
# C:\Users\hgjygj\AppData\Local\Temp/ipykernel_13872/531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# Unnamed: 0               1111.500000
# ref                      1337.010342
# review_date              2013.857914
# cocoa_percent              71.493930
# rating                      3.195856
# counts_of_ingredients       3.075989
# dtype: float64

# %%
data.median()
# Out:
# C:\Users\hgjygj\AppData\Local\Temp/ipykernel_13872/4184645713.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.median()
# Unnamed: 0               1111.50
# ref                      1381.00
# review_date              2014.00
# cocoa_percent              70.00
# rating                      3.25
# counts_of_ingredients       3.00
# dtype: float64

# %%
data.mode()
# Out:
#       Unnamed: 0    ref company company_location  review_date  \
# 0              0  414.0    Soma            U.S.A       2015.0
# 1              1    NaN     NaN              NaN          NaN
# 2              2    NaN     NaN              NaN          NaN
# 3              3    NaN     NaN              NaN          NaN
# 4              4    NaN     NaN              NaN          NaN
# ...          ...    ...     ...              ...          ...
# 2219        2219    NaN     NaN              NaN          NaN
# 2220        2220    NaN     NaN              NaN          NaN
# 2221        2221    NaN     NaN              NaN          NaN
# 2222        2222    NaN     NaN              NaN          NaN
# 2223        2223    NaN     NaN              NaN          NaN
#
#      country_of_bean_origin specific_bean_origin_or_bar_name  cocoa_percent  \
# 0                 Venezuela                       Madagascar           70.0
# ...

# %%
data.std()
# Out:
# C:\Users\hgjygj\AppData\Local\Temp/ipykernel_13872/2723740006.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.std()
# Unnamed: 0               642.157821
# ref                      693.959768
# review_date                3.582151
# cocoa_percent              5.278253
# rating                     0.431509
# counts_of_ingredients      0.929875
# dtype: float64

# %%
data.var()
# Out:
# C:\Users\hgjygj\AppData\Local\Temp/ipykernel_13872/445316826.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.var()
# Unnamed: 0               412366.666667
# ref                      481580.159587
# review_date                  12.831804
# cocoa_percent                27.859950
# rating                        0.186200
# counts_of_ingredients         0.864668
# dtype: float64

# %%
# Correlation
corr = data.corr()
corr
# Out:
#                        Unnamed: 0       ref  review_date  cocoa_percent  \
# Unnamed: 0               1.000000  0.023857     0.023649       0.037437
# ref                      0.023857  1.000000     0.991602       0.054167
# review_date              0.023649  0.991602     1.000000       0.054985
# cocoa_percent            0.037437  0.054167     0.054985       1.000000
# rating                  -0.008715  0.052099     0.053048      -0.074917
# counts_of_ingredients    0.080309 -0.351235    -0.361120      -0.189490
#
#                          rating  counts_of_ingredients
# Unnamed: 0            -0.008715               0.080309
# ref                    0.052099              -0.351235
# review_date            0.053048              -0.361120
# cocoa_percent         -0.074917              -0.189490
# rating                 1.000000              -0.099777
# counts_of_ingredients -0.099777               1.000000
